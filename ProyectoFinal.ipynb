# %% [markdown]
# <a href="https://colab.research.google.com/github/suarez-oa/Proyecto_Final_Henry/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Librerias que se van a utilizar

# %%
import pandas as pd
import json
import numpy as np
import pickle
import pyarrow.parquet as pq

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **creo una funcion para normalizar la columna Category**

# %%
def normalize_categories(category_list):
    if category_list is not None:
        return [category.strip() for category in category_list]
    else:
        return None

# %%
def normalize_hours(hours_list):
    if hours_list is not None:
        normalized_hours = []
        for day_hours in hours_list:
            if len(day_hours) == 2:
                day, hours = day_hours
                normalized_day_hours = f"{day}: {hours}"
                normalized_hours.append(normalized_day_hours)
        return normalized_hours
    else:
        return None

# %% [markdown]
# # **indico que categoria quiero**
# ### importante colocarlo en ingles

# %%
categoria_especifica = 'Tourist attraction'

# %% [markdown]
# # **abro los archivos de meta data 1 - 9**
# #  y normalizo la columna correspondiente

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/1.json','r') as f:
  j1 = [json.loads(line) for line in f]

#Df
df_j1= pd.DataFrame(j1)
df_j1['category'] = df_j1['category'].apply(normalize_categories)
df_meta1 = df_j1.dropna(subset=['category'])
df_meta1 = df_meta1.explode('category')

df_meta1['hours'] = df_meta1['hours'].apply(normalize_hours)
df_meta1['hours'] = df_meta1['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta1['category']
# Out:
# 0                      Pharmacy
# 1              Textile exporter
# 2             Korean restaurant
# 3                  Fabric store
# 4                  Fabric store
#                   ...
# 274999        Kitchen remodeler
# 274999             Lumber store
# 274999              Paint store
# 274999    Plumbing supply store
# 275000         Auto repair shop
# Name: category, Length: 530472, dtype: object

# %%
df_meta_n1 = df_meta1[df_meta1['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n1.head()
# Out:
#                             name  \
# 374   Bremer County Freedom Rock
# 890        Franklin Urban Forest
# 986      Rowell Meadow Trailhead
# 1632    Art Gallery And Oddities
# 1746        Clewiston Recreation
#
#                                                 address  \
# 374       Bremer County Freedom Rock, Readlyn, IA 50668
# 890   Franklin Urban Forest, Dunn St, Franklin, IN 4...
# 986      Rowell Meadow Trailhead, Cedar Grove, CA 93633
# 1632  Art Gallery And Oddities, 1129 Payne Ave, St P...
# 1746  Clewiston Recreation, 110 W Osceola Ave, Clewi...
#
#                                     gmap_id description   latitude  \
# 374   0x87fab955c5f50231:0x45d1db338bbca46f        None  42.706998
# 890   0x886b6f1c70136577:0x1a727e63599f325a        None  39.474827
# 986   0x809563f87bcbbaf3:0xc1b1866d753e666e        None  36.723000
# 1632  0x52b2d53dd2800793:0xd5cad76f06c0d649        None  44.975223
# 1746  0x88dbfbb04ff91adb:0xc860816d4cad29a6        None  26.755649
#
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/2.json','r') as f:
  j2 = [json.loads(line) for line in f]

#Df
df_j2= pd.DataFrame(j2)
df_j2['category'] = df_j2['category'].apply(normalize_categories)
df_meta2 = df_j2.dropna(subset=['category'])
df_meta2 = df_meta2.explode('category')

df_meta2['hours'] = df_meta2['hours'].apply(normalize_hours)
df_meta2['hours'] = df_meta2['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n2 = df_meta2[df_meta2['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n2.head()
# Out:
#                                 name  \
# 32                     Longview Park
# 324      Tait Cummins Sports Complex
# 404  Watts Branch Stream Valley Park
# 470   Berlin Museum of Local History
# 568              Silver Creek Museum
#
#                                                address  \
# 32   Longview Park, 4980 W Gillespie Bridge Rd, Col...
# 324  Tait Cummins Sports Complex, 3000 C St SW, Ced...
# 404  Watts Branch Stream Valley Park, Potomac, MD 2...
# 470  Berlin Museum of Local History, 111 S Adams Av...
# 568  Silver Creek Museum, 2954 S Walnut Rd, Freepor...
#
#                                    gmap_id description   latitude  longitude  \
# 32   0x87dcb5b039efdcf9:0x333ded48f2b0b550        None  38.929301 -92.410065
# 324  0x87e4f7005d792e4d:0x187baf488c1ad2c5        None  41.946628 -91.639889
# 404  0x89b7ccd598200eff:0xe72b0d3b842f61de        None  39.066356 -77.191290
# 470  0x8801452df04609a1:0x34c98dba40f37c34        None  43.967942 -88.945738
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/3.json','r') as f:
  j3 = [json.loads(line) for line in f]

#Df
df_j3= pd.DataFrame(j3)
df_j3['category'] = df_j3['category'].apply(normalize_categories)
df_meta3 = df_j3.dropna(subset=['category'])
df_meta3 = df_meta3.explode('category')

df_meta3['hours'] = df_meta3['hours'].apply(normalize_hours)
df_meta3['hours'] = df_meta3['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n3 = df_meta3[df_meta3['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n3.head()
# Out:
#                            name  \
# 41     Taylor Mountain Overlook
# 409   Alpine Historical Society
# 559              Spicewood Park
# 713  Dude Ranchers' Association
# 715       Welcome to Texas Sign
#
#                                                address  \
# 41   Taylor Mountain Overlook, Blue Ridge Pkwy, Blu...
# 409  Alpine Historical Society, 2116 Tavern Rd, Alp...
# 559         Spicewood Park, Olson Dr, Austin, TX 78750
# 713  Dude Ranchers' Association, 1122 12th St, Cody...
# 715  Welcome to Texas Sign, 3951 Martin Luther King...
#
#                                    gmap_id description   latitude   longitude  \
# 41   0x884d18a3617e93c5:0x36b9ed110dc248ea        None  37.431711  -79.749465
# 409  0x80d960957d348dbb:0x6e7c25cf2357cf4c        None  32.822564 -116.776302
# 559  0x865b3327d75f5bcb:0xff7b6a690ac92f7d        None  30.446438  -97.803969
# 713  0x534c1ed06a6d6f27:0x32a4de60a4e06a9a        None  44.525483 -109.063668
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/4.json','r') as f:
  j4 = [json.loads(line) for line in f]

#Df
df_j4= pd.DataFrame(j3)
df_j4['category'] = df_j4['category'].apply(normalize_categories)
df_meta4 = df_j4.dropna(subset=['category'])
df_meta4 = df_meta4.explode('category')

df_meta4['hours'] = df_meta4['hours'].apply(normalize_hours)
df_meta4['hours'] = df_meta4['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n4 = df_meta4[df_meta4['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n4.head()
# Out:
#                            name  \
# 41     Taylor Mountain Overlook
# 409   Alpine Historical Society
# 559              Spicewood Park
# 713  Dude Ranchers' Association
# 715       Welcome to Texas Sign
#
#                                                address  \
# 41   Taylor Mountain Overlook, Blue Ridge Pkwy, Blu...
# 409  Alpine Historical Society, 2116 Tavern Rd, Alp...
# 559         Spicewood Park, Olson Dr, Austin, TX 78750
# 713  Dude Ranchers' Association, 1122 12th St, Cody...
# 715  Welcome to Texas Sign, 3951 Martin Luther King...
#
#                                    gmap_id description   latitude   longitude  \
# 41   0x884d18a3617e93c5:0x36b9ed110dc248ea        None  37.431711  -79.749465
# 409  0x80d960957d348dbb:0x6e7c25cf2357cf4c        None  32.822564 -116.776302
# 559  0x865b3327d75f5bcb:0xff7b6a690ac92f7d        None  30.446438  -97.803969
# 713  0x534c1ed06a6d6f27:0x32a4de60a4e06a9a        None  44.525483 -109.063668
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/5.json','r') as f:
  j5 = [json.loads(line) for line in f]

#Df
df_j5= pd.DataFrame(j5)
df_j5['category'] = df_j5['category'].apply(normalize_categories)
df_meta5 = df_j5.dropna(subset=['category'])
df_meta5 = df_meta5.explode('category')

df_meta5['hours'] = df_meta5['hours'].apply(normalize_hours)
df_meta5['hours'] = df_meta5['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n5 = df_meta5[df_meta5['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n5.head()
# Out:
#                         name  \
# 23       The SPACESHIP HOUSE
# 397  Historic Montrose Court
# 415        Bicentennial Park
# 461           Community Park
# 747       Roseland Waterpark
#
#                                                address  \
# 23   The SPACESHIP HOUSE, 222 Wright St, Covington,...
# 397  Historic Montrose Court, 1101-, 1151 Boyd St, ...
# 415  Bicentennial Park, B87, 07 -4 -192, Brookhaven...
# 461  Community Park, 460 Lori Ln, Cottage Grove, WI...
# 747  Roseland Waterpark, 250 Eastern Blvd, Canandai...
#
#                                    gmap_id description   latitude  longitude  \
# 23    0x8841b7660845c6ab:0x956fd72dc4c1fc1        None  39.088184 -84.526433
# 397  0x885a7cee14f684c5:0x461d9a3bcb564ae2        None  36.306832 -82.357238
# 415  0x8627d9db75dca167:0xab3e0d7c373af659        None  31.586713 -90.433969
# 461   0x88065bcda1c3fde3:0x9a3314e72767948        None  43.083446 -89.206093
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/6.json','r') as f:
  j6 = [json.loads(line) for line in f]

#Df
df_j6= pd.DataFrame(j6)
df_j6['category'] = df_j6['category'].apply(normalize_categories)
df_meta6 = df_j6.dropna(subset=['category'])
df_meta6 = df_meta6.explode('category')

df_meta6['hours'] = df_meta6['hours'].apply(normalize_hours)
df_meta6['hours'] = df_meta6['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n6 = df_meta6[df_meta6['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n6.head()
# Out:
#                                name  \
# 84                   Covington Park
# 168     Gunnison Valley Observatory
# 520        Cranberry Ridge Overlook
# 737        T Pennington Art Gallery
# 750  Spirit's Promise Equine Rescue
#
#                                                address  \
# 84   Covington Park, 18941 Manchester St, Minnetonk...
# 168  Gunnison Valley Observatory, 2804 Co Rd 38, Gu...
# 520  Cranberry Ridge Overlook, Blue Ridge Pkwy, Mag...
# 737  T Pennington Art Gallery, 15 N Main St, Waynes...
# 750  Spirit's Promise Equine Rescue, 2746 Sound Ave...
#
#                                    gmap_id  \
# 84   0x87f61c38a08c50b3:0x3e5fbc47bf4228aa
# 168  0x873f936b3f9c5f87:0xe846292ab0da4b8e
# 520  0x88596ea274de5575:0x871bdb42751ccc6e
# 737  0x885976d425f5e6d9:0x53a14fef051671e5
# 750  0x89e86034718c2113:0x3ee8a0cdc707e9a5
#
#                                            description   latitude   longitude  \
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/7.json','r') as f:
  j7 = [json.loads(line) for line in f]

#Df
df_j7= pd.DataFrame(j7)
df_j7['category'] = df_j7['category'].apply(normalize_categories)
df_meta7 = df_j7.dropna(subset=['category'])
df_meta7 = df_meta7.explode('category')

df_meta7['hours'] = df_meta7['hours'].apply(normalize_hours)
df_meta7['hours'] = df_meta7['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n7 = df_meta7[df_meta7['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n7.head()
# Out:
#                                      name  \
# 53                      Rock Springs Park
# 150                       Gill Creek Park
# 178  Ash Creek/Riverside Drive Open Space
# 206                  Lake Stephens Marina
# 210                   Alfred Beckley Mill
#
#                                                address  \
# 53   Rock Springs Park, 303 S 5th St, Black River F...
# 150  Gill Creek Park, 3085-3199 Niagara St, Niagara...
# 178  Ash Creek/Riverside Drive Open Space, reversid...
# 206  Lake Stephens Marina, 1400 Lake Stephens Rd, S...
# 210  Alfred Beckley Mill, County Rte 9-7, Beaver, W...
#
#                                    gmap_id  \
# 53   0x87fee6f052573cd9:0xec1946482acd6b5a
# 150  0x89d3429f02e418cf:0x5e59731a17cdf40f
# 178  0x89e8102e20270801:0x8ae2c554717629be
# 206  0x884ef04df8821bb7:0x446aeebcf638ff4b
# 210  0x884e8d279b4fac69:0x6daa7b882e3a4ca3
#
#                                            description   latitude  longitude  \
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/8.json','r') as f:
  j8 = [json.loads(line) for line in f]

#Df
df_j8= pd.DataFrame(j8)
df_j8['category'] = df_j8['category'].apply(normalize_categories)
df_meta8 = df_j8.dropna(subset=['category'])
df_meta8 = df_meta8.explode('category')

df_meta8['hours'] = df_meta8['hours'].apply(normalize_hours)
df_meta8['hours'] = df_meta8['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n8 = df_meta8[df_meta8['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n8.head()
# Out:
#                                 name  \
# 49                McMahon Playground
# 57   Bison's Bluff Nature Playground
# 65             ICT Pop-Up Urban Park
# 119       Harris County War Memorial
# 126    Forest Hill Neighborhood Park
#
#                                                address  \
# 49   McMahon Playground, 55 Cleveland St, Charlesto...
# 57   Bison's Bluff Nature Playground, 1111 E Schaum...
# 65   ICT Pop-Up Urban Park, 121 E Douglas Ave, Wich...
# 119  Harris County War Memorial, 3505 War Memorial ...
# 126  Forest Hill Neighborhood Park, 13232 SE 51st P...
#
#                                    gmap_id  \
# 49   0x88fe7a51c9bd16df:0x8d369b48d84fb59e
# 57   0x880faf00ac5eefab:0x5db786628a78b3c6
# 65   0x87bae3e9c67c91a7:0x4182e518b5bb888f
# 119  0x8640da508272ae4b:0x5d8c97f50f3d04b4
# 126  0x5490694823363239:0x3700ec3b87c653df
#
#                                            description   latitude   longitude  \
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/9.json','r') as f:
  j9 = [json.loads(line) for line in f]

#Df
df_MD_9= pd.DataFrame(j9)
df_MD_9['category'] = df_MD_9['category'].apply(normalize_categories)
df_meta9 = df_MD_9.dropna(subset=['category'])
df_meta9 = df_MD_9.explode('category')

df_meta9['hours'] = df_meta9['hours'].apply(normalize_hours)
df_meta9['hours'] = df_meta9['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n9 = df_meta9[df_meta9['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n9.head()
# Out:
#                           name  \
# 54                 Nu‘u Refuge
# 101       Madonna of the Trail
# 157                Pawlak Park
# 386      Biwabik Park Pavilion
# 456  Hollywood Heritage Museum
#
#                                                address  \
# 54            Nu‘u Refuge, Piilani Hwy, Hana, HI 96713
# 101  Madonna of the Trail, Commerce St, Lexington, ...
# 157           Pawlak Park, W 14th St, Lorain, OH 44052
# 386  Biwabik Park Pavilion, 100 5th Ave S, Biwabik,...
# 456  Hollywood Heritage Museum, 2100 N Highland Ave...
#
#                                    gmap_id  \
# 54   0x7954b910ca77a769:0x2bcd47529cc56e08
# 101  0x87c179ecd21173eb:0x6bede47b68c2327c
# 157  0x88309d07bd02930b:0x54fafd3630e25ad1
# 386  0x52a56763275598bd:0x692be8ca04217648
# 456  0x80c2bee655ecce71:0xa72ee568dea87ae4
#
#                                            description   latitude   longitude  \
# 54                                                None  20.625352 -156.174990
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/10.json','r') as f:
  j10 = [json.loads(line) for line in f]

#Df
df_MD_10= pd.DataFrame(j10)
df_MD_10['category'] = df_MD_10['category'].apply(normalize_categories)
df_meta10 = df_MD_10.dropna(subset=['category'])
df_meta10 = df_meta10.explode('category')

df_meta10['hours'] = df_meta10['hours'].apply(normalize_hours)
df_meta10['hours'] = df_meta10['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n10 = df_meta10[df_meta10['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n10.head()
# Out:
#                                         name  \
# 3                                 Boysen Dam
# 31   Stafford Forge Wildlife Management Area
# 67                  Kelleher Family Vineyard
# 71                          Cayuse Vineyards
# 122                          Brookshire Park
#
#                                                address  \
# 3                       Boysen Dam, Shoshoni, WY 82649
# 31   Stafford Forge Wildlife Management Area, West ...
# 67   Kelleher Family Vineyard, 7377 St Helena Hwy, ...
# 71   Cayuse Vineyards, 17 E Main St, Walla Walla, W...
# 122  Brookshire Park, 250 Brookshire Rd, Boone, NC ...
#
#                                    gmap_id description   latitude   longitude  \
# 3    0x8758af9fcdabbee7:0xefa71efcf509afe8        None  43.416677 -108.177605
# 31   0x89c10423bf3f91f5:0x34d7bb951aa9f0aa        None  39.668262  -74.318788
# 67   0x8084551175ba07fd:0x5a45cee109f523eb        None  38.415731 -122.385601
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/11.json','r') as f:
  j11 = [json.loads(line) for line in f]

#Df
df_MD_11= pd.DataFrame(j11)
df_MD_11['category'] = df_MD_11['category'].apply(normalize_categories)
df_meta11 = df_MD_11.dropna(subset=['category'])
df_meta11 = df_meta11.explode('category')

df_meta11['hours'] = df_meta11['hours'].apply(normalize_hours)
df_meta11['hours'] = df_meta11['hours'].apply(lambda x: ', '.join(x) if x is not None else None)

# %%
df_meta_n11 = df_meta11[df_meta11['category'].str.contains(categoria_especifica, case=False, na=False)]

df_meta_n11
# Out:
#                                                      name  \
# 48                    Saint Anthony Greek Orthodox Church
# 102                                   Newbold-White House
# 106                             Sturgeon Point State Park
# 355                                Memorial Park Baseball
# 414     Cabeza Prieta National Wildlife Refuge Adminis...
# ...                                                   ...
# 274852                                      Stransky Park
# 274904                       Otter Cove Bridge & Causeway
# 274924                  The Great American Scream Machine
# 274975                                 Spring Meadow Park
# 274977                                 Rhine River Cruise
#
#                                                   address  \
# 48      Saint Anthony Greek Orthodox Church, 4795 Lake...
# 102     Newbold-White House, 152 Newbold White Rd, Her...
# 106     Sturgeon Point State Park, 6036 Point Rd, Harr...
# ...

# %%
df_combinado_metadata = pd.concat([df_meta_n1, df_meta_n2, df_meta_n3, df_meta_n4, df_meta_n5, df_meta_n6, df_meta_n7, df_meta_n8, df_meta_n9, df_meta_n10, df_meta_n11], ignore_index=True)

# %%
df_combinado_metadata.head()
# Out:
#                          name  \
# 0  Bremer County Freedom Rock
# 1       Franklin Urban Forest
# 2     Rowell Meadow Trailhead
# 3    Art Gallery And Oddities
# 4        Clewiston Recreation
#
#                                              address  \
# 0      Bremer County Freedom Rock, Readlyn, IA 50668
# 1  Franklin Urban Forest, Dunn St, Franklin, IN 4...
# 2     Rowell Meadow Trailhead, Cedar Grove, CA 93633
# 3  Art Gallery And Oddities, 1129 Payne Ave, St P...
# 4  Clewiston Recreation, 110 W Osceola Ave, Clewi...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x87fab955c5f50231:0x45d1db338bbca46f        None  42.706998  -92.219361
# 1  0x886b6f1c70136577:0x1a727e63599f325a        None  39.474827  -86.057494
# 2  0x809563f87bcbbaf3:0xc1b1866d753e666e        None  36.723000 -118.766000
# 3  0x52b2d53dd2800793:0xd5cad76f06c0d649        None  44.975223  -93.073786
# ...

# %% [markdown]
# # **Abro los archivos de Yelp**

# %%
archivo_pkl = '/content/drive/MyDrive/Colab Notebooks/Yelp/business.pkl'
with open(archivo_pkl, 'rb') as archivo:
    business = pickle.load(archivo)
business = business.loc[:, ~business.columns.duplicated()]

# %%
business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/checkin.json','r') as f:
  jcheckin = [json.loads(line) for line in f]

#Df
df_checkin_Yelp= pd.DataFrame(jcheckin)

# %%
df_checkin_Yelp
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/review.json','r') as f:
  jreview = [json.loads(line) for line in f]

#Df
df_review_Yelp = pd.DataFrame(jreview)

# %%
df_review_Yelp.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/tip.json','r') as f:
  jtip = [json.loads(line) for line in f]

#Df
df_tip_Yelp = pd.DataFrame(jtip)

# %%
df_tip_Yelp.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text                 date  \
# 0                     Avengers time with the ladies.  2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban...  2013-02-05 18:35:10
# 2             It's open even when you think it isn't  2013-08-18 00:56:08
# 3                          Very decent fried chicken  2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch  2012-10-06 19:43:09
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
archivo_parquet = '/content/drive/MyDrive/Colab Notebooks/Yelp/user.parquet'
tabla_parquet = pq.read_table(archivo_parquet)
user = tabla_parquet.to_pandas()

# %%
user.head()
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %% [markdown]
# # **abro los archivos de review florida 1 - 9**

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/1.json','r') as f:
  jflorida1 = [json.loads(line) for line in f]

#Df
df_florida1 = pd.DataFrame(jflorida1)

# %%
df_florida1.head()
# Out:
#                  user_id              name           time  rating  \
# 0  101471856155148729010   Julie A. Gerber  1628003250740       1
# 1  115477234789038326051  Martin Sheffield  1595031217005       5
# 2  101805010244892834381      Brian Truett  1522924253567       5
# 3  106344422881493743981          Tina Sun  1467907819586       1
# 4  100875113069561776529      James Haynes  1480683415081       5
#
#                                                 text  pics  \
# 0  Update: Their “reply” to my review amounted to...  None
# 1  He's a knowledgeable doctor but the way he run...  None
# 2  Best doctor I've ever had, I never wait to be ...  None
# 3  I was told he is a good doctor. I was trying t...  None
# 4  Takes the time to actually get to know his pat...  None
#
#                                                 resp  \
# 0  {'time': 1627042799532, 'text': 'Thank you for...
# 1  {'time': 1582464056733, 'text': 'Thank you for...
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/2.json','r') as f:
  jflorida2 = [json.loads(line) for line in f]

#Df
df_florida2 = pd.DataFrame(jflorida2)

# %%
df_florida2.head()
# Out:
#                  user_id              name           time  rating  text  pics  \
# 0  109529036644141630539        Alan Morin  1473010428117       4  None  None
# 1  115212367853293765185     Marcy Greyson  1573195284103       1  None  None
# 2  115669795459122007893        Serenity A  1595534213620       5  None  None
# 3  107026601493861185081  Bama Urban Quail  1475982438897       3  None  None
# 4  105395352801366805481   Nichole Bentley  1540558962277       5  None  None
#
#                                                 resp  \
# 0  {'time': 1550525663097, 'text': 'At Aspen Run ...
# 1  {'time': 1573498174929, 'text': 'Lavella, we'r...
# 2  {'time': 1595865602041, 'text': 'Thank you for...
# 3  {'time': 1550525650904, 'text': 'Thank you for...
# 4  {'time': 1540572887179, 'text': 'Thank you for...
#
#                                  gmap_id
# 0  0x88ecf453fa2e0e71:0x3e7cc80808a41906
# 1  0x88ecf453fa2e0e71:0x3e7cc80808a41906
# 2  0x88ecf453fa2e0e71:0x3e7cc80808a41906
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/3.json','r') as f:
  jflorida3 = [json.loads(line) for line in f]

#Df
df_florida3 = pd.DataFrame(jflorida3)

# %%
df_florida3.head()
# Out:
#                  user_id              name           time  rating  text  pics  \
# 0  100987328828973274618    Quasha Jackson  1592413625176       5  None  None
# 1  112120799259411888995  Robert McCracken  1477961402026       3  None  None
# 2  103025345644978049366             Tau B  1545107865599       5  None  None
# 3  114814792777059616241     amanda miller  1532716007707       5  None  None
# 4  109094611549368116444    Courtney Coats  1545108790970       5  None  None
#
#                                                 resp  \
# 0  {'time': 1592425025075, 'text': 'Thanks Quasha...
# 1  {'time': 1598374208890, 'text': 'Robert thank ...
# 2  {'time': 1572716768704, 'text': 'Thank you for...
# 3  {'time': 1572717861138, 'text': 'Thanks for th...
# 4  {'time': 1572716704243, 'text': 'Thank you for...
#
#                                  gmap_id
# 0  0x88e5b65aaaaaaaab:0xb5b7a34b160c7c3f
# 1  0x88e5b65aaaaaaaab:0xb5b7a34b160c7c3f
# 2  0x88e5b65aaaaaaaab:0xb5b7a34b160c7c3f
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/4.json','r') as f:
  jflorida4 = [json.loads(line) for line in f]

#Df
df_florida4 = pd.DataFrame(jflorida4)

# %%
df_florida4.head()
# Out:
#                  user_id              name           time  rating  \
# 0  111089986569422827059    Adriana Puello  1562445954625       5
# 1  109765923153367823923      James Kinder  1599073255105       1
# 2  108530578805473384429      FUNFARRIA111  1509854746153       3
# 3  103974205326433604170  maricarmen armas  1553257212461       1
# 4  110871167571028444366  Marlon Furlongue  1502316345039       5
#
#                                                 text  pics  resp  \
# 0  (Translated by Google) It looks clean organize...  None  None
# 1                                               None  None  None
# 2                                               None  None  None
# 3                                               None  None  None
# 4                                               None  None  None
#
#                                 gmap_id
# 0  0x88d9a92de7d83b41:0x294c58cfe237353
# 1  0x88d9a92de7d83b41:0x294c58cfe237353
# 2  0x88d9a92de7d83b41:0x294c58cfe237353
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/5.json','r') as f:
  jflorida5 = [json.loads(line) for line in f]

#Df
df_florida5 = pd.DataFrame(jflorida5)

# %%
df_florida5.head()
# Out:
#                  user_id           name           time  rating  text  pics  \
# 0  113858264176732771479     Leigh hand  1517782070836       5  None  None
# 1  106210922333559842648  Ashley Harvin  1618166009798       5  None  None
# 2  111045799481319444342  Dennis Hodges  1539384246786       5  None  None
# 3  100986245918593061355      Moon Crow  1578116973759       4  None  None
# 4  100557650668280630848   Dennis Arndt  1573694148003       5  None  None
#
#    resp                                gmap_id
# 0  None  0x88e61aa5df038465:0x580976b6e9c5313d
# 1  None  0x88e61aa5df038465:0x580976b6e9c5313d
# 2  None  0x88e61aa5df038465:0x580976b6e9c5313d
# 3  None  0x88e61aa5df038465:0x580976b6e9c5313d
# 4  None  0x88e61aa5df038465:0x580976b6e9c5313d

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/6.json','r') as f:
  jflorida6 = [json.loads(line) for line in f]

#Df
df_florida6 = pd.DataFrame(jflorida6)

# %%
df_florida6.head()
# Out:
#                  user_id             name           time  rating  text  pics  \
# 0  112117413735440637618        JD Howell  1481077537447       5  None  None
# 1  101520668282585770433  Elvio Carrazana  1620952805024       1  None  None
# 2  115286351550709023505       Art Jervis  1572629367281       5  None  None
# 3  116716423597507981462      James Zirin  1477195593056       5  None  None
# 4  102373651401137683434      Angel Ramos  1594479302642       5  None  None
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1621261656395, 'text': 'Hi, Mr. Carra...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                  gmap_id
# 0  0x88d8df729ca5eda7:0x8131504abdbfe7fe
# 1  0x88d8df729ca5eda7:0x8131504abdbfe7fe
# 2  0x88d8df729ca5eda7:0x8131504abdbfe7fe
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/7.json','r') as f:
  jflorida7 = [json.loads(line) for line in f]

#Df
df_florida7 = pd.DataFrame(jflorida7)

# %%
df_florida7.head()
# Out:
#                  user_id            name           time  rating  \
# 0  104742191258708465221     mike furlly  1578355241615       2
# 1  103583292295506230128      Jason Tapp  1601146925438       4
# 2  111788509655582307526          29ricd  1580662302885       5
# 3  106315565206014984497  Joeann Francis  1616898061782       5
# 4  116086452052718128513       Anna Byrd  1582148492922       1
#
#                                                 text  pics  resp  \
# 0  My antenna got damaged cause they never took i...  None  None
# 1                                   Car looks great!  None  None
# 2           Cleaned the car better than I ever could  None  None
# 3                                              Great  None  None
# 4  My car was not cleaned inside well at all. The...  None  None
#
#                                  gmap_id
# 0  0x88e5c501850bc2b3:0x16a7dd8a0d9b8646
# 1  0x88e5c501850bc2b3:0x16a7dd8a0d9b8646
# 2  0x88e5c501850bc2b3:0x16a7dd8a0d9b8646
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/8.json','r') as f:
  jflorida8 = [json.loads(line) for line in f]

#Df
df_florida8 = pd.DataFrame(jflorida8)

# %%
df_florida8.head()
# Out:
#                  user_id            name           time  rating  \
# 0  110470175821229800993      paul lynch  1514980803126       5
# 1  103628617710810564752  Maary Demmings  1497735129902       5
# 2  111870075131039403124    Aaron Wilder  1495653714688       5
# 3  113474874090273849057   PewPew Gaming  1514486733158       1
# 4  113323073967152147756   Lee Rodriguez  1508589294156       5
#
#                                                 text  pics  resp  \
# 0                                       Good service  None  None
# 1                                               Good  None  None
# 2  Went there for work but it was busy and had a ...  None  None
# 3  Horrible service repairs... labor hourly rate ...  None  None
# 4                                     Amazing people  None  None
#
#                                 gmap_id
# 0  0x88de11c0e8d32209:0x7c81f6c83581877
# 1  0x88de11c0e8d32209:0x7c81f6c83581877
# 2  0x88de11c0e8d32209:0x7c81f6c83581877
# ...

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-Florida/8.json','r') as f:
  jflorida9 = [json.loads(line) for line in f]

#Df
df_florida9 = pd.DataFrame(jflorida8)

# %%
df_florida9.head()
# Out:
#                  user_id            name           time  rating  \
# 0  110470175821229800993      paul lynch  1514980803126       5
# 1  103628617710810564752  Maary Demmings  1497735129902       5
# 2  111870075131039403124    Aaron Wilder  1495653714688       5
# 3  113474874090273849057   PewPew Gaming  1514486733158       1
# 4  113323073967152147756   Lee Rodriguez  1508589294156       5
#
#                                                 text  pics  resp  \
# 0                                       Good service  None  None
# 1                                               Good  None  None
# 2  Went there for work but it was busy and had a ...  None  None
# 3  Horrible service repairs... labor hourly rate ...  None  None
# 4                                     Amazing people  None  None
#
#                                 gmap_id
# 0  0x88de11c0e8d32209:0x7c81f6c83581877
# 1  0x88de11c0e8d32209:0x7c81f6c83581877
# 2  0x88de11c0e8d32209:0x7c81f6c83581877
# ...
