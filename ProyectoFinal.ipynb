# %% [markdown]
# <a href="https://colab.research.google.com/github/suarez-oa/Proyecto_Final_Henry/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Librerias que se van a utilizar

# %%
import pandas as pd
import json
import numpy as np
import pickle
import pyarrow.parquet as pq
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **creo una funcion para normalizar la columna Category**

# %%
def normalize_categories(category_list):
    if category_list is not None:
        return [category.strip() for category in category_list]
    else:
        return None

# %%
def normalize_hours(hours_list):
    if hours_list is not None:
        normalized_hours = []
        for day_hours in hours_list:
            if len(day_hours) == 2:
                day, hours = day_hours
                normalized_day_hours = f"{day}: {hours}"
                normalized_hours.append(normalized_day_hours)
        return normalized_hours
    else:
        return None

# %%
def flatten_dict(d):
    if d is None:
        return {}

    flattened_dict = {}
    for key, values in d.items():
        if isinstance(values, list):
            for value in values:
                flattened_dict[f"{key}: {value}"] = 1
        else:
            flattened_dict[key] = values
    return flattened_dict

# %%
def cargar_y_normalizar(ruta_archivo):
    with open(ruta_archivo, 'r') as f:
        j = [json.loads(line) for line in f]
    df = pd.DataFrame(j)
    df['category'] = df['category'].apply(normalize_categories)
    df_meta = df.dropna(subset=['category'])
    df_meta = df_meta.explode('category')
    df_meta = df_meta.drop(columns=['relative_results'])
    df_meta = df_meta.drop(columns=['MISC'])
    df_meta['hours'] = df_meta['hours'].apply(normalize_hours)
    df_meta['hours'] = df_meta['hours'].apply(lambda x: ', '.join(x) if x is not None else None)
    return df_meta

# %% [markdown]
# # **abro los archivos de meta datacompletos**
# #  y normalizo la columna correspondiente

# %%
ruta_archivo1 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/1.json'
ruta_archivo2 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/2.json'
ruta_archivo3 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/3.json'
ruta_archivo4 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/4.json'
ruta_archivo5 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/5.json'
ruta_archivo6 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/6.json'
ruta_archivo7 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/7.json'
ruta_archivo8 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/8.json'
ruta_archivo9 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/9.json'
ruta_archivo10 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/10.json'
ruta_archivo11 = '/content/drive/MyDrive/Colab Notebooks/Google Maps/metadata-sitios/11.json'


df_meta1 = cargar_y_normalizar(ruta_archivo1)
df_meta2 = cargar_y_normalizar(ruta_archivo2)
df_meta3 = cargar_y_normalizar(ruta_archivo3)
df_meta4 = cargar_y_normalizar(ruta_archivo4)
df_meta5 = cargar_y_normalizar(ruta_archivo5)
df_meta6 = cargar_y_normalizar(ruta_archivo6)
df_meta7 = cargar_y_normalizar(ruta_archivo7)
df_meta8 = cargar_y_normalizar(ruta_archivo8)
df_meta9 = cargar_y_normalizar(ruta_archivo9)
df_meta10 = cargar_y_normalizar(ruta_archivo10)
df_meta11 = cargar_y_normalizar(ruta_archivo11)

# %% [markdown]
# # **indico que categoria quiero**
# ### importante colocarlo en ingles
# y concatenamos para tener solo un archivo df

# %%
df_meta1['category']
# Out:
# 0                      Pharmacy
# 1              Textile exporter
# 2             Korean restaurant
# 3                  Fabric store
# 4                  Fabric store
#                   ...
# 274999        Kitchen remodeler
# 274999             Lumber store
# 274999              Paint store
# 274999    Plumbing supply store
# 275000         Auto repair shop
# Name: category, Length: 530472, dtype: object

# %% [markdown]
# 'Tourist attraction'

# %%
categoria_especifica = 'Tourist attraction'

# %%
df_meta_n1 = df_meta1[df_meta1['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n2 = df_meta2[df_meta2['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n3 = df_meta3[df_meta3['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n4 = df_meta4[df_meta4['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n5 = df_meta5[df_meta5['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n6 = df_meta6[df_meta6['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n7 = df_meta7[df_meta7['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n8 = df_meta8[df_meta8['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n9 = df_meta9[df_meta9['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n10 = df_meta10[df_meta10['category'].str.contains(categoria_especifica, case=False, na=False)]
df_meta_n11 = df_meta11[df_meta11['category'].str.contains(categoria_especifica, case=False, na=False)]

df_total_meta = pd.concat([df_meta_n1, df_meta_n2, df_meta_n3, df_meta_n4, df_meta_n5, df_meta_n6, df_meta_n7, df_meta_n8, df_meta_n9, df_meta_n10, df_meta_n11], ignore_index=True)

# %%
df_total_meta
# Out:
#                                     name  \
# 0             Bremer County Freedom Rock
# 1                  Franklin Urban Forest
# 2                Rowell Meadow Trailhead
# 3               Art Gallery And Oddities
# 4                   Clewiston Recreation
# ...                                  ...
# 29618                      Stransky Park
# 29619       Otter Cove Bridge & Causeway
# 29620  The Great American Scream Machine
# 29621                 Spring Meadow Park
# 29622                 Rhine River Cruise
#
#                                                  address  \
# 0          Bremer County Freedom Rock, Readlyn, IA 50668
# 1      Franklin Urban Forest, Dunn St, Franklin, IN 4...
# 2         Rowell Meadow Trailhead, Cedar Grove, CA 93633
# 3      Art Gallery And Oddities, 1129 Payne Ave, St P...
# 4      Clewiston Recreation, 110 W Osceola Ave, Clewi...
# ...                                                  ...
# 29618  Stransky Park, 17th St & Harrison Avenue, Linc...
# 29619  Otter Cove Bridge & Causeway, Park Loop Rd, Mt...
# 29620  The Great American Scream Machine, 275 Riversi...
# 29621  Spring Meadow Park, 3815 Vittoria Way, Newberg...
# 29622  Rhine River Cruise, 1 Busch Gardens Blvd, Will...
#
#                                      gmap_id description   latitude  \
# 0      0x87fab955c5f50231:0x45d1db338bbca46f        None  42.706998
# 1      0x886b6f1c70136577:0x1a727e63599f325a        None  39.474827
# 2      0x809563f87bcbbaf3:0xc1b1866d753e666e        None  36.723000
# 3      0x52b2d53dd2800793:0xd5cad76f06c0d649        None  44.975223
# 4      0x88dbfbb04ff91adb:0xc860816d4cad29a6        None  26.755649
# ...                                      ...         ...        ...
# 29618  0x8796be487a3f4577:0x9cc6f3c18337d563        None  40.786856
# 29619  0x4caeb95910462c8f:0xc9e9f7b4a799591c        None  44.317338
# 29620   0x88f51932d3a6b3ed:0xab77e62c633232c        None  33.766046
# 29621   0x54956a5dbbb2b701:0x8b1af79bc18c85e        None  45.311129
# 29622  0x89b088091163152b:0x7416234b5301e35a        None  37.233303
#
#         longitude            category  avg_rating  num_of_reviews price  \
# 0      -92.219361  Tourist attraction         4.8               5  None
# 1      -86.057494  Tourist attraction         4.6               7  None
# 2     -118.766000  Tourist attraction         4.7               3  None
# 3      -93.073786  Tourist attraction         3.8               6  None
# 4      -80.933920  Tourist attraction         4.1               6  None
# ...           ...                 ...         ...             ...   ...
# 29618  -96.696356  Tourist attraction         4.6             238  None
# 29619  -68.199607  Tourist attraction         4.8              35  None
# 29620  -84.551455  Tourist attraction         3.0             118  None
# 29621 -122.937596  Tourist attraction         4.3              38  None
# 29622  -76.645113  Tourist attraction         4.2              17  None
#
#                                                    hours                state  \
# 0      Thursday: Open 24 hours, Friday: Open 24 hours...        Open 24 hours
# 1      Thursday: 6AM–9PM, Friday: 6AM–9PM, Saturday: ...    Open ⋅ Closes 9PM
# 2                                                   None                 None
# 3                                                   None                 None
# 4                                                   None                 None
# ...                                                  ...                  ...
# 29618  Monday: 8AM–10PM, Tuesday: 8AM–10PM, Wednesday...   Open ⋅ Closes 10PM
# 29619                                               None                 None
# 29620  Monday: Open 24 hours, Tuesday: Open 24 hours,...        Open 24 hours
# 29621  Monday: Open 24 hours, Tuesday: Open 24 hours,...        Open 24 hours
# 29622  Monday: 12–5PM, Tuesday: 12–5PM, Wednesday: 12...  Closed ⋅ Opens 12PM
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 29618  https://www.google.com/maps/place//data=!4m2!3...
# 29619  https://www.google.com/maps/place//data=!4m2!3...
# 29620  https://www.google.com/maps/place//data=!4m2!3...
# 29621  https://www.google.com/maps/place//data=!4m2!3...
# 29622  https://www.google.com/maps/place//data=!4m2!3...
#
# [29623 rows x 13 columns]

# %%
gcloud services enable compute.googleapis.com         \
                        containerregistry.googleapis.com  \
                        aiplatform.googleapis.com \
                        cloudbuild.googleapis.com \
                        cloudfunctions.googleapis.com

# %% [markdown]
# # Guardo la meta data en un CSV temporal esto permite guardarlo en el drive y cuando se ejecuta en el BIGQUERY se actualiza la data de BIGQUERY cuando selecciono la categoria que deseo

# %%
df_total_meta.to_csv('/content/drive/My Drive/Colab Notebooks/metadata.csv', index=False)

# %% [markdown]
# # **abro los archivos de review de cualquier estado y lo guardo en un solo DF**

# %%
estado = 'Florida'

# %%
directorio = f'/content/drive/MyDrive/Colab Notebooks/Google Maps/reviews-estados/review-{estado}'
df_estado = pd.DataFrame()

for archivo_json in os.listdir(directorio):
    if archivo_json.endswith('.json'):
        ruta_completa = os.path.join(directorio, archivo_json)
        with open(ruta_completa, 'r') as f:
            datos = [json.loads(line) for line in f]
            df_temp = pd.DataFrame(datos)

            if 'pics' in df_temp.columns:
                df_temp.drop('pics', axis=1, inplace=True)
            if 'resp' in df_temp.columns:
                df_temp.drop('resp', axis=1, inplace=True)
            if 'gmap_id' in df_temp.columns:
                df_temp.drop('gmap_id', axis=1, inplace=True)

            df_estado = pd.concat([df_estado, df_temp], ignore_index=True)

# %%
df_estado
# Out:
#                        user_id              name           time  rating  \
# 0        101471856155148729010   Julie A. Gerber  1628003250740       1
# 1        115477234789038326051  Martin Sheffield  1595031217005       5
# 2        101805010244892834381      Brian Truett  1522924253567       5
# 3        106344422881493743981          Tina Sun  1467907819586       1
# 4        100875113069561776529      James Haynes  1480683415081       5
# ...                        ...               ...            ...     ...
# 2849995  103990867065092397510    J. B. Oliveira  1503293272680       5
# 2849996  112479723581291238162            Adam K  1514763473117       5
# 2849997  110377147788065022784    English People  1531250213447       5
# 2849998  109919447996049187193           Shiva K  1532621720862       4
# 2849999  116093539979953820587  Tiago nascimento  1577461433361       4
#
#                                                       text
# 0        Update: Their “reply” to my review amounted to...
# 1        He's a knowledgeable doctor but the way he run...
# 2        Best doctor I've ever had, I never wait to be ...
# 3        I was told he is a good doctor. I was trying t...
# 4        Takes the time to actually get to know his pat...
# ...                                                    ...
# 2849995  It is a buyers paradise. Hundred places inside...
# 2849996  Great place to go especially if you're in the ...
# 2849997  I love this place so much and come here alot a...
# 2849998  Plenty of shops with excellent variety, ample ...
# 2849999                                     Nice open mall
#
# [2850000 rows x 5 columns]

# %% [markdown]
# # Guardo el estado en un CSV temporal esto permite guardarlo en el drive y cuando se ejecuta en el BIGQUERY se actualiza la data de BIGQUERY

# %%
df_estado.to_csv('/content/drive/My Drive/Colab Notebooks/estado.csv', index=False)

# %%
ruta_del_archivo = '/content/drive/MyDrive/Colab Notebooks/estado.csv'
df = pd.read_csv(ruta_del_archivo)

# %%
df
# Out:
#                       user_id               name           time  rating  \
# 0       109129804842686204152         Nicki Gore  1566331951619       5
# 1       113240926405758965692      Allen Ratliff  1504917982385       5
# 2       113044837891141253355  Jonathan Tringali  1474765901185       4
# 3       110329155147592031570             S Blad  1472858535682       4
# 4       108989634908602011119     Daniel Formoso  1529649811341       5
# ...                       ...                ...            ...     ...
# 521510  106377858921719724271      Emily Stanker  1595464050942       3
# 521511  118219754689785813975          Jeri Hill  1573608171589       3
# 521512  117055270500346099514     Stas Moszynski  1520481904459       3
# 521513  113033147917777461687        Kalli Kline  1612036301339       4
# 521514  109171932050061786058   Ed ThePopPunkKid  1571068334950       5
#
#                                                      text pics resp  \
# 0       We always stay here when in Valdez for silver ...  NaN  NaN
# 1       Great campground for the price. Nice hot unlim...  NaN  NaN
# 2       We tent camped here for 2 nights while explori...  NaN  NaN
# 3       This place is just a few miles outside Valdez,...  NaN  NaN
# 4       Probably the nicest and cleanest campground we...  NaN  NaN
# ...                                                   ...  ...  ...
# 521510                                                NaN  NaN  NaN
# 521511                                                NaN  NaN  NaN
# 521512                                                NaN  NaN  NaN
# 521513                                                NaN  NaN  NaN
# 521514                                                NaN  NaN  NaN
#
#                                       gmap_id
# 0       0x56b646ed2220b77f:0xd8975e316de80952
# 1       0x56b646ed2220b77f:0xd8975e316de80952
# 2       0x56b646ed2220b77f:0xd8975e316de80952
# 3       0x56b646ed2220b77f:0xd8975e316de80952
# 4       0x56b646ed2220b77f:0xd8975e316de80952
# ...                                       ...
# 521510  0x540c25a454fb47cf:0xf0788e2fb7ba1907
# 521511  0x540c25a454fb47cf:0xf0788e2fb7ba1907
# 521512  0x540c25a454fb47cf:0xf0788e2fb7ba1907
# 521513  0x540c25a454fb47cf:0xf0788e2fb7ba1907
# 521514  0x540c25a454fb47cf:0xf0788e2fb7ba1907
#
# [521515 rows x 8 columns]

# %% [markdown]
# # **Abro los archivos de Yelp**

# %%
archivo_pkl = '/content/drive/MyDrive/Colab Notebooks/Yelp/business.pkl'
with open(archivo_pkl, 'rb') as archivo:
    business = pickle.load(archivo)
business = business.loc[:, ~business.columns.duplicated()]
business = business.drop(columns=['attributes'])
business = business.drop(columns=['hours'])

# %%
business['categories']
# Out:
# 0         Doctors, Traditional Chinese Medicine, Naturop...
# 1         Shipping Centers, Local Services, Notaries, Ma...
# 2         Department Stores, Shopping, Fashion, Home & G...
# 3         Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                                 Brewpubs, Breweries, Food
#                                 ...
# 150341                           Nail Salons, Beauty & Spas
# 150342    Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343    Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344    Fitness/Exercise Equipment, Eyewear & Optician...
# 150345    Beauty & Spas, Permanent Makeup, Piercing, Tattoo
# Name: categories, Length: 150346, dtype: object

# %% [markdown]
# # selecciono la categoria de yelp que deseo seleccionar al igual de meta data

# %%
categoria_especifica_yelp = 'recreation'

# %%
business = business[business['categories'].str.contains(categoria_especifica_yelp, case=False, na=False)]

# %%
business
# Out:
#                    business_id  \
# 528     kxvOUehCtJAL2nYKkeiR-w
# 615     82suwumWp1MEq04QhiS9DQ
# 635     xHspDrdyq1g27yRDezB5yA
# 813     6jomGWEI4ryImrWPguUQQQ
# 1915    vfBzDd-ceWnCrKqHdZwMSg
# ...                        ...
# 144674  v-GUuEdEQ4RLcdbjUy84Kg
# 145224  WtmmtVkui7AjVIZvnqQHwg
# 145817  Q0mebaho7udFFvKNn36t1w
# 147482  Arx7AUZaiY6v-E9jNw8bYw
# 148680  Q13D46ovD8YF3S2rYlbLZQ
#
#                                                      name  \
# 528                                           Incrediplex
# 615                        Surreal Virtual Reality Studio
# 635                                         Kaiserman JCC
# 813                           Santa Barbara Athletic Club
# 1915                                       Wasting Arrows
# ...                                                   ...
# 144674                                    CSA Palm Harbor
# 145224                            Get Air King of Prussia
# 145817                        Post Road Recreation Center
# 147482  Richard A. Carlucci Recreation And Aquatic Center
# 148680                                Gretna Bingo Palace
#
#                     address             city state postal_code   latitude  \
# 528       6002 Sunnyside Rd     Indianapolis    NJ       46236  39.866083
# 615     436 State St, Ste B    Santa Barbara    MO       93101  34.416782
# 635         45 Haverford Rd     Philadelphia    PA       19096  39.982542
# 813         520 Castillo St    Santa Barbara    NJ       93101  34.413384
# 1915        5260 Longley Ln             Reno    PA       89502  39.474317
# ...                     ...              ...   ...         ...        ...
# 144674         1500 16th St      Palm Harbor    IL       34683   28.08153
# 145224   555 S Henderson Rd  King of Prussia    FL       19406  40.080087
# 145817       4700 N Post Rd     Indianapolis    FL       46226  39.841741
# 147482        651 Vestal Rd       Plainfield    PA       46168  39.708806
# 148680    1900 Franklin Ave           Gretna    PA       70053   29.91964
#
#          longitude stars review_count is_open  \
# 528     -85.975098   4.0           33       0
# 615    -119.695139   5.0           30       0
# 635     -75.268542   3.5           11       1
# 813    -119.700341   3.0           55       1
# 1915     -119.7637   4.5           93       1
# ...            ...   ...          ...     ...
# 144674  -82.757815   3.5            6       1
# 145224  -75.356335   2.5           85       0
# 145817  -86.008825   2.5            9       0
# 147482  -86.412776   4.5           10       1
# 148680  -90.048577   4.5            5       1
#
#                                                categories
# 528     Specialty Schools, Education, Gyms, Sports Clu...
# 615     Recreation Centers, Arts & Entertainment, Virt...
# 635     Preschools, Recreation Centers, Education, Gym...
# 813     Fitness & Instruction, Swimming Pools, Active ...
# 1915    Sporting Goods, Archery, Active Life, Recreati...
# ...                                                   ...
# 144674                    Recreation Centers, Active Life
# 145224  Trampoline Parks, Active Life, Recreation Centers
# 145817  Recreation Centers, Haunted Houses, Active Lif...
# 147482    Active Life, Recreation Centers, Swimming Pools
# 148680  Amusement Parks, Recreation Centers, Bingo Hal...
#
# [244 rows x 12 columns]

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/checkin.json','r') as f:
  jcheckin = [json.loads(line) for line in f]

df_checkin_Yelp= pd.DataFrame(jcheckin)

# %%
df_checkin_Yelp
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# 131927  2011-05-24 01:35:13, 2012-01-01 23:44:33, 2012...
# 131928           2016-12-03 23:33:26, 2018-12-02 19:08:45
# 131929                                2015-01-06 17:51:53
#
# [131930 rows x 2 columns]

# %% [markdown]
# # Combino la tabla de Business y chekin mediante Business_id y se guarda solo los datos que corresponde a la categoria seleccionada

# %%
combined_df = df_checkin_Yelp.merge(business, on='business_id', how='inner')

# %%
combined_df
# Out:
#                 business_id  \
# 0    -AdaSS3N7OsgnBGqh5EMQg
# 1    -GB_KiOOFoGdW09uuarqjQ
# 2    0HAkgEHkJaazbxlX88m5BA
# 3    0XazM8VIswiJZ4-96raOjQ
# 4    0atrthcpxRQ3MiwgSY3zYg
# ..                      ...
# 235  xKpE6XPxZugTet-iZ6pEiw
# 236  xW4SUlN-xMJplSdXw_TMVw
# 237  xgmjCPInj447lZStaxau0Q
# 238  zGvBaY28FqD__tImfy7GuA
# 239  zwgd1Mf1NeGV4IgD3P9UlA
#
#                                                   date  \
# 0    2011-11-30 23:52:26, 2011-12-09 22:43:39, 2012...
# 1    2010-11-20 21:11:03, 2011-03-12 03:26:01, 2011...
# 2    2010-10-24 22:23:33, 2010-11-06 20:42:28, 2010...
# 3    2016-08-07 00:24:13, 2016-10-23 18:47:28, 2016...
# 4    2011-06-25 15:58:23, 2011-07-14 18:42:35, 2011...
# ..                                                 ...
# 235  2012-08-03 23:49:52, 2012-11-10 18:55:31, 2013...
# 236  2018-01-27 04:29:11, 2018-02-16 02:40:54, 2018...
# 237  2012-07-12 01:00:39, 2012-07-19 02:46:48, 2013...
# 238  2012-06-12 00:39:38, 2013-01-02 01:33:34, 2013...
# 239  2011-03-14 21:45:36, 2011-03-28 21:38:21, 2011...
#
#                                       name                     address  \
# 0                              Indy Island           8575 E Raymond St
# 1                       Carmel Ice Skadium             1040 3rd Ave SW
# 2                Horsethief Reservoir Camp             1177 W State St
# 3                       Empower Adventures          423 Lafayette Blvd
# 4                    Boise Army Navy Store         4924 W Chinden Blvd
# ..                                     ...                         ...
# 235                   eXplore Brown County       2620 Valley Branch Rd
# 236                          The Axe House  20 Meremac Valley Plaza Dr
# 237               SportsPlex At Warminster                 654 York Rd
# 238  Carrillo Recreation Center & Ballroom           100 E Carrillo St
# 239            RiverWinds Community Center          1000 RiverWinds Dr
#
#               city state postal_code   latitude   longitude stars  \
# 0     Indianapolis    PA       46239  39.737863  -86.016596   2.5
# 1           Carmel    AZ       46032  39.964864  -86.132364   2.5
# 2            Boise    PA       83702  43.620636 -116.205342   5.0
# 3          Oldsmar    TN       34677  28.027533  -82.658917   5.0
# 4      Garden City    PA       83714  43.641464 -116.264792   3.5
# ..             ...   ...         ...        ...         ...   ...
# 235      Nashville    FL       47448  39.661431  -86.093684   4.5
# 236    Valley Park    MO       63088  38.548151  -90.492464   5.0
# 237     Warminster    AB       18974  40.209669  -75.100502   2.5
# 238  Santa Barbara    MO       93101  34.422636 -119.700179   4.5
# 239  West Deptford    FL       08086  39.859015  -75.205815   4.0
#
#     review_count is_open                                         categories
# 0              7       1  Recreation Centers, Active Life, Amateur Sport...
# 1             32       1  Sporting Goods, Recreation Centers, Skating Ri...
# 2              8       1  Active Life, Local Services, Recreation Center...
# 3            127       1  Ziplining, Team Building Activities, Kids Acti...
# 4              9       1  Recreation Centers, Hotels & Travel, Hiking, S...
# ..           ...     ...                                                ...
# 235           47       1  Venues & Event Spaces, Paintball, Recreation C...
# 236           38       1  Recreation Centers, Active Life, Arts & Entert...
# 237            8       1  Recreation Centers, Active Life, Soccer, Summe...
# 238            6       1  Recreation Centers, Venues & Event Spaces, Act...
# 239           13       1  Rock Climbing, Active Life, Recreation Centers...
#
# [240 rows x 13 columns]

# %%
combined_df.to_csv('/content/drive/My Drive/Colab Notebooks/yelp checkin business.csv', index=False)

# %% [markdown]
# ## Abro el archico review y se concatena con la tabla business mediante business_id y se guarda los review de la categoria seleccionada

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/review.json','r') as f:
  jreview = [json.loads(line) for line in f]

df_review_Yelp = pd.DataFrame(jreview)
df_review_Yelp = df_review_Yelp.drop(columns=['stars'])
df_review_Yelp = df_review_Yelp.drop(columns=['cool'])
df_review_Yelp = df_review_Yelp.drop(columns=['funny'])
df_review_Yelp = df_review_Yelp.drop(columns=['date'])

# %%
df_review_Yelp.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'useful', 'text'], dtype='object')

# %%
combined_df_business_reviwes = df_review_Yelp.merge(business, on='business_id', how='inner')

# %%
combined_df_business_reviwes
# Out:
#                    review_id                 user_id             business_id  \
# 0     dwgJ7B_r3iuIqX0VpCoRTA  qfm3p0svZIueCPof6Lgjkw  vfBzDd-ceWnCrKqHdZwMSg
# 1     h0MUOFC_dlKD2ZrP-1gPZw  LZy_pm56qCPpQWvImsDgHw  vfBzDd-ceWnCrKqHdZwMSg
# 2     3gz1KS0nA8HFxqfylomnfg  5WYuAdX1R659ZjweIybCFA  vfBzDd-ceWnCrKqHdZwMSg
# 3     9STZfMS-J-aYMySwuAkO_w  npKQGzsxzY8YYksISe0Mxw  vfBzDd-ceWnCrKqHdZwMSg
# 4     8tTLVNLfVoNPvSPhqx_fOg  q3Nqj4xXAq2pYVI-khbkcQ  vfBzDd-ceWnCrKqHdZwMSg
# ...                      ...                     ...                     ...
# 6681  21xZNqczzs_k9IE7Xmjc0A  r3pgJEFzADeZDHC3vmwEaQ  Psfpa1WrrRqHULwnZvxJGQ
# 6682  GeJY9VIkjkJM1Edrm6izWg  Mwc3W-KNn37iaSMZu8Tm8Q  Psfpa1WrrRqHULwnZvxJGQ
# 6683  JrUm-0YLYDIOyNg5Zrerug  -4QpB9l-jPXjUBwr_lMXgQ  Psfpa1WrrRqHULwnZvxJGQ
# 6684  p8k9M2PxfvSDoiMMwduwcQ  V24kKkZHJaWwtrT6lETaFQ  Psfpa1WrrRqHULwnZvxJGQ
# 6685  ilc1SXnmJrWlYGg-0ODHEA  NLoqvArgYHa6Jjz-Hg2xvw  Psfpa1WrrRqHULwnZvxJGQ
#
#       useful                                               text  \
# 0          1  We went there with several family members and ...
# 1          0  This place is great. The staff is friendly and...
# 2          1  I have spent a lot more money for a lot less f...
# 3          0  My mom bought a groupon for archery lessons an...
# 4          0  We had fun.  First timers and an early Valenti...
# ...      ...                                                ...
# 6681       1  We've been here a couple dozen times and reall...
# 6682       4  We had a wonderful time during our first visit...
# 6683       1  My husband and I were running out of ideas for...
# 6684       1  Great place for child development and meaningf...
# 6685       3  We were invited to a birthday party at Wonder ...
#
#                  name                    address  city state postal_code  \
# 0      Wasting Arrows            5260 Longley Ln  Reno    PA       89502
# 1      Wasting Arrows            5260 Longley Ln  Reno    PA       89502
# 2      Wasting Arrows            5260 Longley Ln  Reno    PA       89502
# 3      Wasting Arrows            5260 Longley Ln  Reno    PA       89502
# 4      Wasting Arrows            5260 Longley Ln  Reno    PA       89502
# ...               ...                        ...   ...   ...         ...
# 6681  Wonder & Unwind  890 E Patriot Blvd, Ste A  Reno    PA       89511
# 6682  Wonder & Unwind  890 E Patriot Blvd, Ste A  Reno    PA       89511
# 6683  Wonder & Unwind  890 E Patriot Blvd, Ste A  Reno    PA       89511
# 6684  Wonder & Unwind  890 E Patriot Blvd, Ste A  Reno    PA       89511
# 6685  Wonder & Unwind  890 E Patriot Blvd, Ste A  Reno    PA       89511
#
#        latitude   longitude stars review_count is_open  \
# 0     39.474317   -119.7637   4.5           93       1
# 1     39.474317   -119.7637   4.5           93       1
# 2     39.474317   -119.7637   4.5           93       1
# 3     39.474317   -119.7637   4.5           93       1
# 4     39.474317   -119.7637   4.5           93       1
# ...         ...         ...   ...          ...     ...
# 6681  39.458938 -119.775819   5.0           25       1
# 6682  39.458938 -119.775819   5.0           25       1
# 6683  39.458938 -119.775819   5.0           25       1
# 6684  39.458938 -119.775819   5.0           25       1
# 6685  39.458938 -119.775819   5.0           25       1
#
#                                              categories
# 0     Sporting Goods, Archery, Active Life, Recreati...
# 1     Sporting Goods, Archery, Active Life, Recreati...
# 2     Sporting Goods, Archery, Active Life, Recreati...
# 3     Sporting Goods, Archery, Active Life, Recreati...
# 4     Sporting Goods, Archery, Active Life, Recreati...
# ...                                                 ...
# 6681  Active Life, Playgrounds, Indoor Playcentre, K...
# 6682  Active Life, Playgrounds, Indoor Playcentre, K...
# 6683  Active Life, Playgrounds, Indoor Playcentre, K...
# 6684  Active Life, Playgrounds, Indoor Playcentre, K...
# 6685  Active Life, Playgrounds, Indoor Playcentre, K...
#
# [6686 rows x 16 columns]

# %%
combined_df_business_reviwes.to_csv('/content/drive/My Drive/Colab Notebooks/yelp review business.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Abro el archico tip y se concatena con la tabla business mediante business_id y se guarda los tip de la categoria seleccionada

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/Yelp/tip.json','r') as f:
  jtip = [json.loads(line) for line in f]

df_tip_Yelp = pd.DataFrame(jtip)
df_tip_Yelp = df_tip_Yelp.drop(columns=['compliment_count'])
df_tip_Yelp = df_tip_Yelp.drop(columns=['date'])

# %%
df_tip_Yelp.to_csv('/content/drive/My Drive/Colab Notebooks/yelp tip.csv', index=False)

# %%
df_tip_Yelp
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text
# 0                          Avengers time with the ladies.
# 1       They have lots of good deserts and tasty cuban...
# 2                  It's open even when you think it isn't
# 3                               Very decent fried chicken
# 4                  Appetizers.. platter special for lunch
# ...                                                   ...
# 908910              Disappointed in one of your managers.
# 908911                            Great food and service.
# 908912                                Love their Cubans!!
# 908913                            Great pizza great price
# 908914                  Food is good value but a bit hot!
#
# [908915 rows x 3 columns]

# %%
combined_df_business_tip = df_tip_Yelp.merge(business, on='business_id', how='inner')

# %%
combined_df_business_tip
# Out:
#                      user_id             business_id  \
# 0     DgmAhT4MwtS_aywueKbo3A  eBrjs8r9JXwv99dRvAAQFQ
# 1     _14wp3McW-kk7foNA9A2KQ  eBrjs8r9JXwv99dRvAAQFQ
# 2     _14wp3McW-kk7foNA9A2KQ  eBrjs8r9JXwv99dRvAAQFQ
# 3     M36aMuK9Pnmgb5g6KsJChQ  eBrjs8r9JXwv99dRvAAQFQ
# 4     W4UM_H06wErDAI8ocO3Jdg  eBrjs8r9JXwv99dRvAAQFQ
# ...                      ...                     ...
# 1018  rNHWNfl70xSc6MelxOn-oQ  WtmmtVkui7AjVIZvnqQHwg
# 1019  XF4Hlwa8v7Yto_NPeilpaA  WtmmtVkui7AjVIZvnqQHwg
# 1020  X9RcZ1Lzi6v04eO6ozOFfg  btSVzz8X49MmJyDkBlfoow
# 1021  oNNa6SWGFjlx5b1AW_n85A  btSVzz8X49MmJyDkBlfoow
# 1022  13XMbOp7Qw2qAF-rdRp-Yw  YBvJfo9_d4RmARyFNgqrHQ
#
#                                                    text  \
# 0                                        Parking sucks!
# 1     One dodgeball arena. Three basketball hoops. T...
# 2     Just dont like the new setup with foam pis. No...
# 3                                 Soft opening tonight!
# 4     My kids love this place. We had a great time f...
# ...                                                 ...
# 1018                   So much fun! I highly recommend.
# 1019                               This place is great!
# 1020  Great experience and had SO much fun. Highly r...
# 1021  Great experience, fair pricing, and amazing se...
# 1022  I got my axe kicked at stumpys in West Chester...
#
#                                        name             address  \
# 0                                    EZ Air  895 E Patriot Blvd
# 1                                    EZ Air  895 E Patriot Blvd
# 2                                    EZ Air  895 E Patriot Blvd
# 3                                    EZ Air  895 E Patriot Blvd
# 4                                    EZ Air  895 E Patriot Blvd
# ...                                     ...                 ...
# 1018                Get Air King of Prussia  555 S Henderson Rd
# 1019                Get Air King of Prussia  555 S Henderson Rd
# 1020               BlueWall Virtual Reality      5967 E 82nd St
# 1021               BlueWall Virtual Reality      5967 E 82nd St
# 1022  Stumpy's Hatchet House - West Chester     706 E Market St
#
#                  city state postal_code   latitude   longitude stars  \
# 0                Reno    FL       89511  39.459175 -119.776653   4.0
# 1                Reno    FL       89511  39.459175 -119.776653   4.0
# 2                Reno    FL       89511  39.459175 -119.776653   4.0
# 3                Reno    FL       89511  39.459175 -119.776653   4.0
# 4                Reno    FL       89511  39.459175 -119.776653   4.0
# ...               ...   ...         ...        ...         ...   ...
# 1018  King of Prussia    FL       19406  40.080087  -75.356335   2.5
# 1019  King of Prussia    FL       19406  40.080087  -75.356335   2.5
# 1020     Indianapolis    CA       46250  39.904639  -86.065405   5.0
# 1021     Indianapolis    CA       46250  39.904639  -86.065405   5.0
# 1022     West Chester    NV       19382    39.9645  -75.593277   4.5
#
#      review_count is_open                                         categories
# 0              82       0  Recreation Centers, Trampoline Parks, Fitness ...
# 1              82       0  Recreation Centers, Trampoline Parks, Fitness ...
# 2              82       0  Recreation Centers, Trampoline Parks, Fitness ...
# 3              82       0  Recreation Centers, Trampoline Parks, Fitness ...
# 4              82       0  Recreation Centers, Trampoline Parks, Fitness ...
# ...           ...     ...                                                ...
# 1018           85       0  Trampoline Parks, Active Life, Recreation Centers
# 1019           85       0  Trampoline Parks, Active Life, Recreation Centers
# 1020           28       0  Arts & Entertainment, Recreation Centers, Virt...
# 1021           28       0  Arts & Entertainment, Recreation Centers, Virt...
# 1022            8       1  Active Life, Event Planning & Services, Axe Th...
#
# [1023 rows x 14 columns]

# %%
combined_df_business_tip.to_csv('/content/drive/My Drive/Colab Notebooks/yelp tip business.csv', index=False)

# %% [markdown]
# ## Abro el archico user y se concatena con la tabla tip mediante user_id y se guarda los user de la categoria seleccionada

# %%
archivo_parquet = '/content/drive/MyDrive/Colab Notebooks/Yelp/user.parquet'
tabla_parquet = pq.read_table(archivo_parquet)
user = tabla_parquet.to_pandas()

# %%
user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# 3        2005-11-29 04:38:33     512    330    299
# 4        2007-01-05 19:40:59      29     15      7
# ...                      ...     ...    ...    ...
# 2105592  2012-01-19 23:33:02      74      9      6
# 2105593  2009-06-09 16:34:54      14      5      2
# 2105594  2013-08-13 23:18:11       4      1      2
# 2105595  2015-01-10 00:06:25      21      2      5
# 2105596  2015-11-30 21:10:17      27      1     17
#
#                                                      elite  \
# 0                                                     2007
# 1        2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2                                 2009,2010,2011,2012,2013
# 3                                           2009,2010,2011
# 4
# ...                                                    ...
# 2105592
# 2105593
# 2105594
# 2105595
# 2105596
#
#                                                    friends  fans  ...  \
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52  ...
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28  ...
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1  ...
# ...                                                    ...   ...  ...
# 2105592                             kmwNG5LZSHFmveg6wYYdrw     0  ...
# 2105593  BFYdCAMFyjYHDwesndEXEg, _9fTIqfSJc7g3V_o76XRVg...     1  ...
# 2105594  bKV3ly2MuK-K1cptMrFknQ, liel18zRoSB4tEkUP7i6Cg...     0  ...
# 2105595  dzHTk52vbGtbktRm_B-wEg, fOfFLV7IbBDN6lzARaLqdg...     0  ...
# 2105596  pou3BbKsIozfH50rxmnMew, JT3rDC7-hprCSObnihMeHw...     3  ...
#
#          compliment_more  compliment_profile  compliment_cute  \
# 0                     65                  55               56
# 1                    264                 184              157
# 2                     13                  10               17
# 3                      4                   1                6
# 4                      1                   0                0
# ...                  ...                 ...              ...
# 2105592                1                   0                0
# 2105593                1                   0                0
# 2105594                0                   0                0
# 2105595                0                   0                0
# 2105596                0                   1                0
#
#          compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0                     18              232               844              467
# 1                    251             1847              7054             3131
# 2                      3               66                96              119
# 3                      2               12                16               26
# 4                      0                1                 1                0
# ...                  ...              ...               ...              ...
# 2105592                0                1                 4                0
# 2105593                0                0                 1                0
# 2105594                0                1                 0                0
# 2105595                0                0                 1                0
# 2105596                0                0                 1                0
#
#          compliment_funny  compliment_writer  compliment_photos
# 0                     467                239                180
# 1                    3131               1521               1946
# 2                     119                 35                 18
# 3                      26                 10                  9
# 4                       0                  0                  0
# ...                   ...                ...                ...
# 2105592                 0                  1                  0
# 2105593                 0                  0                  0
# 2105594                 0                  0                  0
# 2105595                 0                  0                  0
# 2105596                 0                  1                  0
#
# [2105597 rows x 22 columns]

# %%
combined_df_tip_user = user.merge(combined_df_business_tip, on='user_id', how='inner')

# %%
combined_df_tip_user
# Out:
#                      user_id    name_x  review_count_x        yelping_since  \
# 0     j14WgRoU_-2ZE1aw1dXrJg    Daniel            4333  2009-01-25 04:35:42
# 1     j14WgRoU_-2ZE1aw1dXrJg    Daniel            4333  2009-01-25 04:35:42
# 2     j14WgRoU_-2ZE1aw1dXrJg    Daniel            4333  2009-01-25 04:35:42
# 3     j14WgRoU_-2ZE1aw1dXrJg    Daniel            4333  2009-01-25 04:35:42
# 4     j14WgRoU_-2ZE1aw1dXrJg    Daniel            4333  2009-01-25 04:35:42
# ...                      ...       ...             ...                  ...
# 1759  CfNY3VpJECGoJKm2rSCgHA  Terrance               2  2019-05-25 15:16:04
# 1760  rNHWNfl70xSc6MelxOn-oQ    Audrey               6  2012-04-19 23:56:00
# 1761  XF4Hlwa8v7Yto_NPeilpaA      Matt               2  2012-05-13 03:52:08
# 1762  EsCk7btRfGlgH4cgeb4DPg      Pete               1  2018-04-19 12:18:58
# 1763  hDNh-XAKd4bftVBsXt7i3A   Jeffrey               5  2016-04-03 17:24:26
#
#       useful  funny   cool                                              elite  \
# 0      43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 1      43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2      43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 3      43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 4      43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# ...      ...    ...    ...                                                ...
# 1759       2      0      0
# 1760       2      0      1
# 1761       6      4      4
# 1762       0      0      0
# 1763       0      0      0
#
#                                                 friends  fans  ...  \
# 0     ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 1     ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2     ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 3     ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 4     ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# ...                                                 ...   ...  ...
# 1759                                               None     0  ...
# 1760                                               None     0  ...
# 1761                                               None     0  ...
# 1762                                               None     0  ...
# 1763                                               None     0  ...
#
#                         address             city  state  postal_code  \
# 0                1401 Clark Ave      Saint Louis     NJ        63103
# 1                1401 Clark Ave      Saint Louis     NJ        63103
# 2             1302 Gallatin Ave        Nashville     FL        37206
# 3             1302 Gallatin Ave        Nashville     FL        37206
# 4                1401 Clark Ave      Saint Louis     NJ        63103
# ...                         ...              ...    ...          ...
# 1759  1719 Washington Ave, Fl 2     Philadelphia     TN        19146
# 1760         555 S Henderson Rd  King of Prussia     FL        19406
# 1761         555 S Henderson Rd  King of Prussia     FL        19406
# 1762  1719 Washington Ave, Fl 2     Philadelphia     TN        19146
# 1763    91 Seaboard Ln, Ste 103        Brentwood     PA        37027
#
#        latitude  longitude  stars  review_count_y  is_open  \
# 0     38.626917 -90.202488    4.0              16        1
# 1     38.626917 -90.202488    4.0              16        1
# 2     36.193147 -86.744564    4.5              63        1
# 3     36.193147 -86.744564    4.5              63        1
# 4     38.626917 -90.202488    4.0              16        1
# ...         ...        ...    ...             ...      ...
# 1759   39.93883  -75.17232    5.0             153        1
# 1760  40.080087 -75.356335    2.5              85        0
# 1761  40.080087 -75.356335    2.5              85        0
# 1762   39.93883  -75.17232    5.0             153        1
# 1763  35.965811 -86.815948    3.5              33        1
#
#                                              categories
# 0     Professional Sports Teams, Event Planning & Se...
# 1     Professional Sports Teams, Event Planning & Se...
# 2     Venues & Event Spaces, Event Planning & Servic...
# 3     Venues & Event Spaces, Event Planning & Servic...
# 4     Professional Sports Teams, Event Planning & Se...
# ...                                                 ...
# 1759  Local Flavor, Recreation Centers, Amateur Spor...
# 1760  Trampoline Parks, Active Life, Recreation Centers
# 1761  Trampoline Parks, Active Life, Recreation Centers
# 1762  Local Flavor, Recreation Centers, Amateur Spor...
# 1763  Recreation Centers, Arts & Entertainment, Part...
#
# [1764 rows x 35 columns]

# %%
combined_df_tip_user.to_csv('/content/drive/My Drive/Colab Notebooks/yelp user tip.csv', index=False)
